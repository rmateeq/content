# %% [markdown]
# ## **Session 11**
# **30, 31 December 2023, and 02 January 2024**
# ### **Project-2 Walkthrough (1/2)**
# # **Create Your Own Image Classifier**
#
# Welcome to the **first walkthrough session** for the Image Classifier project. In this session,
# - we'll walk through **every step** necessary to successfully complete the initial development phase of the image classifier using deep learning techniques.
# - we are committed to covering the **practical aspects** of implementing the image classifier
# - we shall also delving into the relevant **neural network concepts and PyTorch** functionalities.
#
# Let's dive in and unravel the fascinating world of image classification with PyTorch!

# %% [markdown]
# # **List of Steps**
#
# **Step: 0**
# - *Understand the basics*
#
# **Step: 1**
# - *Open online workspace*
#
# **Step: 2**
# - *Initial Setup*
#
# **Step: 3**
# - *Traininig your Classifier*
#
# **Step: 4**
# - *Testing your Classifier*
#
# **Step: 5**
# - *Saving and Loading the Checkpoint*
#
# **Step: 6**
# - *Using the Classifier for Inference*
#
# **Step: 7**
# - *Command Line App*
#
# **Step: 8**
#
# **Step: 9**
#
# **Step:10**

# %% [markdown]
# ## 🚶📖✍ **Step 0 Starts** 🚶📖✍

# %% [markdown]
# ## **Step 0: Understand the Basics**
# - Relevant Sections in Online Classroom
#   1. Instructor [**skip it**]
#   2. Project Intro [**can skip - nice to have a look**]
#   3. Introduction to GPU Workspaces [**can skip - important things are covered here**]
#   4. Updating to PyTorch 0.4 [**skip it**]
#   5. Image Classifier - Part 1 - Development [**can skip - important things are covered here**]

# %% [markdown]
# ### **Project Description**
#
# #### **Section: 5. Image Classifier - Part 1 - Development**
#
# 1. **Objective:**
#    - Develop an image classifier using deep learning in PyTorch.
#    - You are given a dataset of flowers with 102 categories.
#
# 2. **Project Structure:**
#    - Divided into two parts, with Part 1 focusing on the initial development phase using Jupyter notebook.
#
# 3. **File Management in Workspace:**
#    - Do not save large files in the workspace to prevent backup issues.
#    - Beware of the size of model checkpoints, and focus on network architecture to control file size.
#    - Checking file sizes using the terminal command `ls -lh`. If a checkpoint exceeds 1 GB, optimize the classifier network and resave the checkpoint.
#
# 4. **Final Deliverables:**
#     - Completed Jupyter notebook (an HTML version required for submission (Part 1)).

# %% [markdown]
# #### **Section: 3. Introduction to GPU Workspaces**
#
# 1. **Overview:**
#    - You need GPU to train your own model and workspace provides it.
#     - GPU hours are limited (remaining hours are shown at the bottom).
#     - Whenever you open workspace, you are asked if you want to **`Enable GPU`**? Do not enable it until you really understand that you need it!
#
# 2. **Key Notes:**
#    - Only 3 GB storage in the home folder.
#    - Workspace sessions auto-terminate after inactivity, avoiding unnecessary time allocation.
#
# 3. **Session Activity:**
#    - Workspace disconnects after 30 minutes of inactivity.
#    - Regularly check or stay on the workspace page during long tasks to prevent disconnection.
#    - GPU mode persists even after closing notebooks (can only be stopped with the GPU toggle).
#    - Save results promptly to avoid loss after the active process ends.

# %% [markdown]
# 4. **Project Submission:**
#    - Some workspaces allow direct project submission by clicking the "Submit Project" button.
#    - Ensure all required files, including conversions (e.g., ipynb to HTML), are included in the submission.
#
# 5. **Terminal Access:**
#    - Workspaces support multiple views, including file browser, notebook view, and shell terminals.
#    - Terminal accessed through the "New" menu.
#
# 6. **Resetting Data:**
#    - "Menu" button at the bottom left allows workspace resetting.
#    - "Refresh Workspace" has no effect on changes, while "Reset Data" discards all changes (requires confirmation).
#    - Strong recommendation to download work before resetting data.

# %% [markdown]
# ### ✌✈ ***:Step 0 Completed*** ✌✈

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 🚶📖✍ **Step 1 Starts** 🚶📖✍

# %% [markdown]
# ## **Step 1: Open Online Workspace**
# - Relevant Sections in Online Classroom
#   6. Image Classifier - Part 1 - Workspace [**Everything is to be implemented here**]

# %% [markdown]
# <u>**Step 1.1**</u>
# - Once you click on this item [**6. Image Classifier - Part 1 - Workspace**] from menu or click **next** from previous item [**5. Image Classifier - Part 1 - Development**], the first thing you see is this:
#
# <div align="center">
# <img src=data:image/png;base64,... width="450" height="400">
#
# </div>
#
# - Opt for <u>**"Don't Allow"**</u>. You will learn when to use it as you spend time with the project in the workspace.

# %% [markdown]
# - This will start loading the workspace and you will see this kind of progress bar
#
# <div align="center">
# <img src=data:image/png;base64,... width="350" height="120">
# </div>
#
# - Once the progress completes, you will see this:
#
# <div align="center">
# <img src=data:image/png;base64,... width="750" height="220">

# %% [markdown]
# <u>**Step 1.2**</u>
# - Click on <u><b>"home"</b></u> and then click on <u><b>"aipnd-project"</b></u> and the click on <u><b>"Image Classifier Project.ipynb"</b></u> notebook to open it within the workspace. Having opened it will look like this:
#
# <div align="center">
# <img src=data:image/png;base64,... width="700" height="430">
# </div>

# %% [markdown]
# ### ✌✈ ***:Step 1 Completed*** ✌✈

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 🚶📖✍ **Step 2 Starts** 🚶📖✍

# %% [markdown]
# ## **Step 2: Initial Setup**
# - Imports, Data Loading, and Preparation for Training
# - Relevant Sections in Online Classroom
#   6. Image Classifier - Part 1 - Workspace [**Everything is to be implemented here**]

# %% [markdown]
# <u>**Step 2.0 Read Description:**</u>
# - You are provided with the intro text at the begining. You may read it to warm up and out of interest or may ignore it. There is nothing that you don't know about proceeding with the project.
#
# ---

# %% [markdown]
# <u>**Step 2.1 Imports:**</u>
#
# The first code cell asks you to place all the libraries that you import here. You may keep adding the import statements as you implement your code needing more libraries. Some hints are dropped here:
# 1. **Matplotlib for Visualization:**
#   - Utilize `%matplotlib inline` to enable inline plotting.
#
# 2. **PyTorch for Deep Learning:** Import essential modules from the PyTorch library.
#  - `torch` for the core functionality.
#  - `nn` for defining neural network modules.
#  - `optim` for optimization algorithms.
#  - `F` for additional functional operations.

# %% [markdown]
# 3. **torchvision for Datasets and Models:** Import necessary components from the torchvision library.
#  - `datasets` for handling datasets.
#  - `transforms` for data preprocessing.
#  - `models` for accessing pre-trained models.
#
# 4. **Additional Libraries:**
#  - `numpy` for numerical operations on arrays.
#  - `json` for handling JSON data.
#  - `Image` module from the PIL library for image processing.
#
# 5. **Utilizing Pre-trained Models:**
#  - Import specific modules to work with pre-trained models in torchvision.
#  - `torchvision.models` for accessing pre-defined models.
#
#
#  ---

# %% [markdown]
# <u>**Step 2.2 Paths to Data:**</u>
#
# - The next code cell specifies the paths to `train`, `valid`, and `test` data as follows:
#
#   ```
#     data_dir = 'flowers'
#     train_dir = data_dir + '/train'
#     valid_dir = data_dir + '/valid'
#     test_dir = data_dir + '/test'
#   ```
# - You do not need to do anything here. Just take a note of the paths and move on to next step.
#
# ---

# %% [markdown]
# <u>**Step 2.3 Get Your Data Ready for Training and Testing:**</u>
#
# It has three parts specifically as listed below:
#
# 2.3.1. **Data Transforms (data_transforms):**
#    - **Objective:** Define transformations for the training, validation, and testing sets.
#    - **Steps:**
#      - Utilize the torchvision.transforms module to specify the transformations.
#      - Common transformations include resizing, cropping, normalization, and data augmentation.
#      - These transforms enhance the model's ability to generalize from the given datasets.

# %% [markdown]
# 2.3.2. **Loading Datasets (image_datasets):**
#    - **Objective:** Load the datasets using the `ImageFolder` class.
#    - **Steps:**
#      - Utilize the `datasets.ImageFolder` class from the torchvision library.
#      - Provide the path to the root directory containing the dataset.
#      - Ensure the data is organized in subdirectories, where each subdirectory represents a class (category) of images.
#      - This step prepares the datasets for training, validation, and testing.
#
# 2.3.3. **Defining Data Loaders (dataloaders):**
#    - **Objective:** Define data loaders using the loaded datasets and the specified transforms.
#    - **Steps:**
#      - Utilize `torch.utils.data.DataLoader`.
#      - Specify the batch size, shuffle option, and other relevant parameters.
#      - Data loaders are crucial for efficient iteration through the dataset during training, validation, and testing phases.
#      - The dataloaders enable the model to process batches of data, improving training efficiency.

# %% [markdown]
# <div align="center"><big><b>Let's discuss these 3 steps one by one below</b></big></div>
#
# <u>**Step 2.3.1 Data Transforms (`data_transforms`):**</u>
#
# It is optional to apply transformations to `valid` data. Possible transformations are explained below with an indication to whether they apply to `train`, `test`, or both data.
#
#    - **Random Rotation:** [`train`]
#      - **Purpose:** Introduces variability by randomly rotating the image by a maximum of 30 degrees.
#      - **Benefit:** Augments the dataset, helping the model generalize better to rotated versions of the training images.
#
#    - **Random Resized Crop (to 224x224):** [`train`]
#      - **Purpose:** Randomly crops and resizes the image to 224x224 pixels.
#      - **Benefit:** Provides robustness to variations in object size and location, enhancing the model's ability to recognize objects in different contexts.

# %% [markdown]
#    - **Random Horizontal Flip:** [`train`]
#      - **Purpose:** Randomly flips the image horizontally.
#      - **Benefit:** Augments the dataset with horizontally flipped versions, improving the model's ability to handle images with varying orientations.
#
#    - **To Tensor:** [`both`]
#      - **Purpose:** Converts the image to a PyTorch tensor.
#      - **Benefit:** Transforms the image into a format suitable for input to a neural network, enabling efficient computation during training.
#
#    - **Normalize:** [`both`]
#      - **Purpose:** Normalizes the pixel values of the image.
#      - **Benefit:** Standardizes the input data, making it centered around zero with a standard deviation of 1. This aids in stable and faster convergence during model training.

# %% [markdown]
#    - **Resize (to 255):** [`test`]
#      - **Purpose:** Resizes the image to a fixed size of 255 pixels.
#      - **Benefit:** Ensures consistency in the input size for testing, facilitating uniform processing during model evaluation.
#
#    - **Center Crop (to 224x224):** [`test`]
#      - **Purpose:** Crops the center of the image to 224x224 pixels.
#      - **Benefit:** Similar to the training set, provides a standardized input size for testing, ensuring compatibility with the model architecture.

# %% [markdown]
# **A Note on Normalization**
#
# **Why Normalize Images:**
# Normalization of images is crucial for standardizing pixel values, ensuring that they fall within a consistent and manageable range. This process aids in stabilizing and expediting the convergence of neural network models during training.
#
# **Effect of Normalization on Pixel Value Range:**
# Normalization scales the pixel values, typically bringing them to a range centered around zero with a standard deviation of 1. This standardized range prevents numerical instability during computations and enables more efficient weight updates in the training process.
#
# **Normalization Values `[0.485, 0.456, 0.406], [0.229, 0.224, 0.225]`:**
# These specific values are derived from the mean and standard deviation of the ImageNet dataset, which is a widely used dataset for training deep learning models. Using these values helps align the input data distribution with what the pre-trained models have been trained on. This alignment is essential for effective transfer learning, where a pre-trained model is fine-tuned on a new dataset, ensuring the model adapts smoothly to the new data distribution.

# %% [markdown]
# **To Summarise:**
# The specified data transformations, applied during both training and testing, serve the purpose of augmenting the training dataset, ensuring standardized input sizes, and normalizing pixel values. These transformations contribute to improved model generalization, robustness, and consistent performance during both training and evaluation phases.

# %% [markdown]
# <FONT COLOR="RED">**Here is the sample pseudocode for step 2.3.1**
#
# ```
# train_transforms = CombineTransforms([
#     RandomRotation(max_angle=30),
#     RandomResizedCrop(size=224),
#     RandomHorizontalFlip(),
#     ToTensor(),
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# ])
#
# test_transforms = CombineTransforms([
#     Resize(size=255),
#     CenterCrop(size=224),
#     ToTensor(),
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# ])
# ```
#
# ---

# %% [markdown]
# <u>**2.3.2. Loading Datasets (`image_datasets`):**</u>
#
#    - **Objective:**
#      - Load the `train`, `valid`, and `test` datasets using the `ImageFolder` class from the torchvision.datasets module.
#      - Apply the specified transformations defined as `train_transforms`, and `valid_transforms`, and `test_transforms` during loading.
#
#    - **Benefit:**
#      - The `ImageFolder` class simplifies the process of loading image datasets organized in a folder structure.
#      - Applying `transforms` ensures that images undergo the defined transformations (e.g., rotation, resizing, normalization) before being used in the relevant steps (training, validation, or testing).
#      - Transformed training data enhances model robustness by introducing variations and preprocessing.
#      - The `test_transforms` ensure that validation images are consistently preprocessed, aligning with the transformations applied to the test set.
#      - Consistent preprocessing aids in fair evaluation of the model's performance during validation.

# %% [markdown]
# <FONT COLOR="RED">**Here is the sample pseudocode for step 2.3.2**
#
# ```
# train_data = LoadImageFolderDataset(train_directory, transforms=train_transforms)
# valid_data = LoadImageFolderDataset(validation_directory, transforms=test_transforms)
# test_data = LoadImageFolderDataset(test_directory, transforms=test_transforms)
# ```
#
# **Note:**
# - `LoadImageFolderDataset` is a placeholder for the mechanism in PyTorch that loads an image folder dataset.
# - `train_transforms` and `test_transforms` are the transformations defined earlier for the training and test sets, respectively.
# - The actual implementation will involve using PyTorch's dataset loading utilities and specifying the correct paths and transformations.
#
# ---

# %% [markdown]
# <u>**2.3.3. Defining Data Loaders (dataloaders):**</u>
#
#    - **Objective:**
#      - Create a data loader for the training dataset `train_data`, `valid_data`, and `test_data` using `torch.utils.data.DataLoader`.
#      - Set the batch size to 64 for processing multiple images in parallel.
#      - Enable shuffling of the dataset `shuffle=True` for `train_data` to introduce randomness and prevent the model from memorizing the order of data.
#
#    - **Benefit:**
#      - The data loaders facilitate efficient iteration over the dataset in batches.
#      - Shuffling the `train_data` helps prevent the model from learning patterns based on the order of data, promoting better generalization.
#      - Consistent batch sizes aid in fair evaluation and comparison of the model's performance on validation data.
#      - Consistency in batch size ensures fair comparison with the validation set and helps gauge the model's generalization to new data.

# %% [markdown]
# <FONT COLOR="RED">**Here is the sample pseudocode for step 2.3.3**
#
# ```
# trainloader = CreateDataLoader(train_data, batch_size=64, shuffle=True)
# validloader = CreateDataLoader(valid_data, batch_size=64)
# testloader = CreateDataLoader(test_data, batch_size=64)
# ```
#
# **Note:**
# - `CreateDataLoader` is a placeholder for the mechanism in PyTorch that creates a data loader.
# - The actual implementation involves using PyTorch's `DataLoader` utility with the correct dataset and parameters.
# - Choice of `batch_size` can impact the training process significantly in terms of resource needs.
#
# ---

# %% [markdown]
# **Multiple Choice Questions:**
#
# 1. **What does the term "transform" refer to in the context of image classification with PyTorch?**
#    - A. A neural network layer
#    - B. Image preprocessing operations
#    - C. Loss function
#    - D. Model training algorithm
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: B**

# %% [markdown]
# 2. **Why is it recommended to avoid leaving extremely large .pth files in the /home/workspace directory in the classroom workspace?**
#    - A. It affects model training speed
#    - B. It may cause issues with workspace backups
#    - C. It improves GPU performance
#    - D. It is a requirement for PyTorch
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: B**

# %% [markdown]
# 3. **What is the purpose of the `transforms.Normalize` operation in image preprocessing?**
#    - A. Increase image resolution
#    - B. Adjust image brightness
#    - C. Normalize pixel values for consistent scaling
#    - D. Convert images to grayscale
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: C**

# %% [markdown]
# 4. **In the provided transform code, what does `transforms.RandomResizedCrop(224)` do during training?**
#    - A. Randomly rotates the image by 30 degrees
#    - B. Resizes the image to a random size and aspect ratio
#    - C. Randomly flips the image horizontally
#    - D. Applies random resized cropping to the image
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: B**

# %% [markdown]
# 5. **Why is it important to use the `torch.utils.data.DataLoader` in PyTorch when working with datasets?**
#    - A. To define neural network architectures
#    - B. To create GPU instances
#    - C. To load and batch data efficiently for training
#    - D. To perform image transformations
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: C**

# %% [markdown]
# 6. **What is the purpose of the `datasets.ImageFolder` in PyTorch when loading datasets?**
#    - A. Normalize image pixel values
#    - B. Apply data augmentation techniques
#    - C. Load images and their labels from a specified directory structure
#    - D. Resize images to a fixed size
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: C**

# %% [markdown]
# 7. **In the provided loading datasets code, what does `datasets.ImageFolder(train_dir, transform=train_transforms)` do?**
#    - A. Loads images from the training directory with specified transformations
#    - B. Defines the architecture of the neural network
#    - C. Resizes images to a fixed size during training
#    - D. Applies random resized cropping during validation
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: A**

# %% [markdown]
# 8. **Why is normalization applied to image data during preprocessing?**
#    - A. To increase image contrast
#    - B. To reduce computational complexity
#    - C. To scale pixel values for consistent model training
#    - D. To convert images to grayscale
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: C**

# %% [markdown]
# 9. **What are the recommended values `[0.485, 0.456, 0.406], [0.229, 0.224, 0.225]` used for normalization in PyTorch?**
#    - A. Random initialization values
#    - B. Mean and standard deviation values for ImageNet data
#    - C. Values for resizing images
#    - D. Activation function parameters
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: B**

# %% [markdown]
# <u>**2.4 Label Mapping:**</u>
#
# The next code cell contains the following code snippet for label mapping with an explanation given under the code:
# ```
# import json
#
# with open('cat_to_name.json', 'r') as f:
#     cat_to_name = json.load(f)
# ```
#
# - **Objective:**
#    - Load a mapping from category labels to category names for better human-readable interpretation of model predictions.
#    - The mapping is stored in a JSON file named 'cat_to_name.json.'

# %% [markdown]
# - **Code Explanation:**
#    - `cat_to_name = json.load(f)`:
#      - Use the `json.load()` function to load the content of the JSON file into a Python dictionary (`cat_to_name`).
#      - The dictionary maps integer-encoded categories (labels) to the corresponding actual names of the flowers.
#
# - **Benefit:**
#    - The `cat_to_name` dictionary provides a human-readable mapping, making it easier to interpret the model's predictions.
#    - During model evaluation, the integer-encoded categories predicted by the model can be looked up in this dictionary to retrieve the actual names of the flowers.
#
# - **Example Usage:**
#    - If the model predicts a category label '3,' looking up `cat_to_name[3]` will give the actual name of the flower corresponding to label `3`, i.e., `canterbury bells`.
#
# ---

# %% [markdown]
# ### ✌✈ ***:Step 2 Completed*** ✌✈

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### **Let's breathe and see what's ahead!**
#
# ## **Building and Training the Classifier**
#
# The task involves constructing and training a classifier for flower image recognition. The process includes loading a pre-trained convolutional neural network (CNN), defining a new feed-forward classifier, training the classifier layers using backpropagation with the pre-trained network's features, and optimizing hyperparameters for improved model performance.
#
# Let's get into it!

# %% [markdown]
# ## 🚶📖✍ **Step 3 Starts** 🚶📖✍

# %% [markdown]
# ## **Step 3: Creating and Training the Model**
#
# 3.1 **Load a Pre-trained Network:**
#    - Load a pre-trained convolutional neural network (CNN) from `torchvision.models`.
#    - Choose an appropriate pre-trained model as a starting point (e.g., VGG networks).
#
# 3.2 **Define a New Classifier:**
#    - Define a new, untrained feed-forward network to act as a classifier.
#    - Specify the architecture of the classifier, utilizing ReLU activations and dropout for regularization.
#    - Ensure that only the weights of the feed-forward network are updated during training.
#
# 3.3 **Train the Classifier Layers:**
#    - Implement backpropagation to train the classifier layers using the pre-trained network's features.
#    - Utilize the training data to update the weights of the classifier layers.
#    - Monitor and track the loss and accuracy on the validation set during training.
#    - Experiment with different hyperparameters (e.g., learning rate, units in the classifier, epochs) to find the optimal model.

# %% [markdown]
# <u>**Step 3.1 Load a Pre-Trained CNN**</u>
#
# 1. **Meaning:**
#    - Loading a pre-trained model from `torchvision.models` involves obtaining a pre-trained convolutional neural network (CNN) architecture that has been trained on a large dataset, often for image classification tasks. These models are part of the PyTorch `torchvision` library and are based on well-established architectures. A list of models to choose from is given below.
#
# 2. **Importance:**
#    - **Transfer Learning:**
#      - The pre-trained models serve as powerful feature extractors because they have already learned hierarchical and generic features from diverse images. This is a form of transfer learning.
#      - Leveraging these pre-trained features can significantly enhance the performance of a model on a specific task with a limited amount of task-specific data.
#
#    - **Saving Training Time:**
#      - Training a deep neural network from scratch can be computationally expensive and time-consuming. Using a pre-trained model allows skipping the initial training phase on a large dataset, reducing the overall training time.
#
#    - **Effective Feature Extraction:**
#      - Pre-trained models capture low-level features (edges, textures) to high-level features (object parts, objects) through their convolutional layers. This learned representation can be highly effective for various image-related tasks.
#
#    - **Broad Applicability:**
#      - Models like VGG, ResNet, and others available in `torchvision.models` have been successfully applied to diverse computer vision tasks beyond image classification, such as object detection, segmentation, and feature extraction.
#
# 3. **How to Use:**
#    - Once loaded, the pre-trained model can be customized for a specific task by replacing or modifying its final layers (classifier) to suit the desired output format (e.g., the number of classes for classification).
#
#    - The loaded model's weights and architecture can be used as a starting point for further training on a task-specific dataset, retaining the knowledge gained during the pre-training phase.
#
# 4. **Examples of Pre-trained Models:**
#    - Common pre-trained models include VGG, ResNet, Inception, and others. For example, `torchvision.models.vgg16(pretrained=True)` loads the pre-trained VGG-16 model.
#
# **To Summarise**, loading a pre-trained model from `torchvision.models` is a practical approach to benefit from pre-learned features and architectures, accelerating model training and improving performance on specific tasks, such as the image classification task in this project.

# %% [markdown]
# **List of Possible Models to Choose from**
# <div align="center">
#
# | Model                | Description                                               | Last Layer Output Size |
# |----------------------|-----------------------------------------------------------|------------------------|
# | resnet18             | ResNet-18                                                 | 512                    |
# | alexnet              | AlexNet                                                   | 256                    |
# | vgg16                | VGG-16                                                    | 4096                   |
# | densenet121          | DenseNet-121                                              | 1024                   |
# | vgg13                | VGG-13                                                    | 4096                   |
# | vgg11                | VGG-11                                                    | 4096                   |
# | resnet34             | ResNet-34                                                 | 512                    |
# | densenet169          | DenseNet-169                                              | 1664                   |
# | densenet201          | DenseNet-201                                              | 1920                   |
# | densenet161          | DenseNet-161                                              | 2208                   |
# | vgg19                | VGG-19                                                    | 4096                   |
# | resnet50             | ResNet-50                                                 | 2048                   |
# | resnet101            | ResNet-101                                                | 2048                   |
# | resnet152            | ResNet-152                                                | 2048                   |
#
# </div>
#
# Note: The output size refers to the dimensionality of the features produced by the last layer before the classifier in each respective model. The values are indicative and may vary depending on the specific model implementation.

# %% [markdown]
# <FONT COLOR="RED">**Here is the sample pseudocode for step 3.1**
# ```
# # Set the computation device to GPU 'cuda' or 'cpu' as convenient
# device = 'cuda'
#
# # Load a pre-trained model from torchvision.models
# model = LoadPretrainedModel()
#
# # Freeze the parameters of the loaded model
# for each parameter in model.parameters():
#     SetRequiresGradFalse(parameter)
# ```

# %% [markdown]
# **Explanation of the Code:**
#
# 1. **Explanation:**
#    - The code initializes a model pre-trained on ImageNet and specifies that computations should be performed on the 'cuda' device (GPU). **Beware of GPU usage as hours are limited. You may re-assign it with `cpu` as convenient.**
#    - By freezing the parameters (`requires_grad = False`), the pre-trained weights in the model's layers are retained and not updated during the subsequent training steps. This is a common practice in transfer learning, where the goal is to leverage pre-trained features for a specific task without modifying the pre-trained weights.
#
# 2. **Purpose:**
#    - The frozen pre-trained model serves as the feature extractor, and a new classifier will be added and trained for the specific flower classification task. This allows leveraging the generalization power of the pre-trained model while adapting the model to the characteristics of the flower dataset.
#
# ---

# %% [markdown]
# <u>**Step 3.2 Define a New Classifier:**</u>
#
#
# 1. **Replace Default Classifier:**
#    - Replace the default classifier of the pre-trained model with a new classifier defined using `nn.Sequential`.
#    - The new classifier consists of fully connected (linear) layers, ReLU activation, dropout for regularization, and a final linear layer with LogSoftmax activation.
#
# 2. **Sequential Layers:**
#    - Add a fully connected layer that takes the input size of `in_shape` (output size of the last convolutional layer before the classifier) and outputs `out_shape` features.
#    - Apply the Rectified Linear Unit (ReLU) activation function to introduce non-linearity.
#    - Apply dropout with a suitable probability during training to prevent overfitting.
#    - Add another fully connected layer that reduces the features to the desired output size of 102 (number of flower classes).
#    - Apply LogSoftmax activation along the second dimension (classes).
#
# 3. **Loss Function and Optimizer:**
#    - Define the Negative Log Likelihood Loss as the criterion for training the model. This loss is suitable for classification problems with LogSoftmax activation.
#    - Use the Adam optimizer to update the parameters of the newly added classifier during backpropagation. The learning rate can be choosen empirically.
#
# 4. **Move Model to GPU:**
#    - Move the entire model (including the newly added classifier) to the specified device (CPU/GPU). This ensures that both model architecture and computations are on the specified device.
#
# 5. **Benefits:**
#    - **Customization:** The new classifier is tailored for the specific flower classification task, allowing the model to adapt to the characteristics of the dataset.
#    - **Transfer Learning:** The pre-trained convolutional layers retain knowledge from ImageNet, while the new classifier is fine-tuned for the flower dataset, leveraging both general and task-specific features.
#    - **Regularization:** Dropout introduces regularization during training, preventing overfitting and improving model generalization.
#    - **Loss and Optimization:** NLLLoss is appropriate for the LogSoftmax activation, and Adam optimizer efficiently updates the parameters during training.

# %% [markdown]
# <FONT COLOR="RED">**Here is the sample pseudocode for step 3.2**
# ```
# # Replace the default classifier in the pre-trained model
# model.classifier = CreateNewClassifier()
#
# # Define the architecture of the new classifier
# func CreateNewClassifier():
#     return Sequential(
#         LinearLayer(input_size=in_shape, output_size=out_shape),
#         ReLU(),
#         Dropout(probability=0.4),
#         LinearLayer(input_size=out_shape, output_size=102),
#         LogSoftmax(dim=1)
#     )
#
# # Define the Negative Log Likelihood Loss as the criterion
# criterion = ...
#
# # Use the Adam optimizer for updating classifier parameters
# optimizer = ...
#
# # Move the entire model to the specified device (e.g., GPU)
# ...
#
# ```

# %% [markdown]
# **Explaination of the Code:**
#
# 1. **Replace Classifier:**
#    - The default classifier in the pre-trained model is replaced with a new classifier designed for the specific classification task.
#
# 2. **Define New Classifier Architecture:**
#    - The new classifier is defined using fully connected layers with ReLU activation, dropout for regularization, and LogSoftmax activation for the final layer.
#
# 3. **Loss and Optimizer:**
#    - The Negative Log Likelihood Loss is chosen as the criterion, suitable for classification with LogSoftmax activation.
#    - The Adam optimizer is used to efficiently update the parameters of the newly added classifier during training.

# %% [markdown]
# 4. **Move to GPU:**
#    - The entire model, including the custom classifier, is moved to the specified device (e.g., GPU) to ensure efficient computations.
#
# **Why:**
#    - **Customization:** Replacing the classifier tailors the model for the specific task, allowing it to learn features relevant to flower classification.
#    - **Transfer Learning:** The pre-trained convolutional layers retain knowledge from ImageNet, while the new classifier is fine-tuned for the flower dataset, combining general and task-specific knowledge.
#    - **Regularization:** Dropout in the classifier prevents overfitting during training.
#    - **Optimization:** Adam optimizer efficiently updates parameters, facilitating faster convergence during training.
#
# ---

# %% [markdown]
# **Multiple Choice Questions:**
#
# 1. **What is the purpose of loading a mapping from category label to category name using `json.load` in PyTorch image classification?**
#    - A. To visualize model architecture
#    - B. To display images in a grid
#    - C. To interpret the model's predictions with human-readable class names
#    - D. To create additional image transformations
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: C**

# %% [markdown]
# 2. **Why is transfer learning with a pre-trained model beneficial in the context of image classification tasks?**
#    - A. It reduces the need for image preprocessing
#    - B. It accelerates model training time
#    - C. It leverages knowledge learned on a large dataset for a new task
#    - D. It eliminates the need for data augmentation
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: C**

# %% [markdown]
# 3. **What does the code `models.densenet121(pretrained=True)` do in PyTorch?**
#    - A. Defines a new, untrained feed-forward network
#    - B. Initializes a pre-trained DenseNet model
#    - C. Performs random rotations on images
#    - D. Applies dropout to the classifier
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: B**

# %% [markdown]
# 4. **What is the purpose of freezing parameters with `param.requires_grad = False` in PyTorch model initialization?**
#    - A. To prevent backpropagation through the entire network
#    - B. To allow unrestricted parameter updates during training
#    - C. To speed up model training
#    - D. To enable data augmentation
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: A**

# %% [markdown]
# 5. **What does the code `model.classifier = nn.Sequential(...)` achieve in PyTorch model building?**
#    - A. Defines image transformations
#    - B. Initializes a new pre-trained model
#    - C. Adds a custom classifier to the pre-trained model
#    - D. Applies normalization to the input data
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: C**

# %% [markdown]
# 6. **Why is it important to use dropout (`nn.Dropout`) in the model's classifier during training?**
#    - A. It accelerates model training
#    - B. It reduces overfitting by randomly dropping out neurons
#    - C. It applies random rotations to input data
#    - D. It enhances image resolution
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: B**

# %% [markdown]
# 7. **What does the code `optimizer = optim.Adam(model.classifier.parameters(), lr=0.003)` specify in PyTorch model training?**
#    - A. Learning rate for the optimizer
#    - B. Loss function for the model
#    - C. Activation function for the classifier
#    - D. Image transformation parameters
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: A**

# %% [markdown]
# 8. **In PyTorch model training, why is it recommended to try different hyperparameters such as learning rate and units in the classifier?**
#     - A. It reduces the number of training epochs required
#     - B. It speeds up model convergence
#     - C. It helps find the optimal model for the specific task
#     - D. It eliminates the need for validation checks
#
# <details>
# <summary>Click to reveal the answer</summary>
#     - **Correct Option: C**

# %% [markdown]
# <u>**Step 3.3 Train the Classifier:**</u>
#
# In the training phase, the classifier for the flower recognition model is fine-tuned over five epochs. Each epoch involves iterating through batches of training data, updating the model parameters through backpropagation and optimization. Validation is performed at regular intervals to monitor the model's performance on unseen data. Key statistics, including training and validation loss, as well as accuracy, are printed to provide insights into the model's progress. Proper state management ensures correct behavior of layers like dropout during training and evaluation. The process aims to optimize the classifier for accurate flower classification, leveraging transfer learning from a pre-trained model while tailoring it to the specific task at hand.

# %% [markdown]
# **Here are the details:**
#
# 1. **Initialization:**
#    - Initialize the number of training epochs (a short value between 5 and 10 should do in general).
#    - Initialize counters for steps, running loss, and specify the validation frequency (could be between 5 to 20 in general).
#
# 2. **Epoch Loop:**
#    - Iterate over the specified number of epochs.
#
# 3. **Training Loop:**
#    - Iterate over batches of training data.
#    - Increment the step counter.
#    - Move input data and labels to the specified device (e.g., GPU).
#
# 4. **Zero Gradient, Forward Pass, Backward Pass, and Optimization:**
#    - Zero out gradients to avoid accumulation.
#    - Perform a forward pass to obtain log probabilities.
#    - Calculate the loss using Negative Log Likelihood Loss.
#    - Perform a backward pass to compute gradients.
#    - Update model parameters using the optimizer.

# %% [markdown]
# 5. **Running Loss Accumulation:**
#    - Accumulate the running loss for the current batch.
#
# 6. **Validation Checkpoint:**
#    - Check if it's time to perform validation based on the specified frequency.
#    - Initialize variables for validation loss and accuracy.
#    - Set the model to evaluation mode.
#    - Disable gradient computation during validation.
#    - Iterate over batches of validation data.
#    - Calculate validation loss and accuracy.
#    - Print training and validation statistics.
#
# 7. **Model State Management:**
#    - Reset the running loss for the next set of training steps.
#    - Set the model back to training mode.
#
# **Benefits:**
#    - **Iterative Training:** Incremental updates to model parameters using batches of training data.
#    - **Validation Monitoring:** Periodic validation checks to monitor model performance on unseen data.
#    - **Printed Statistics:** Displaying key statistics provides insights into model training progress.
#    - **Model State Management:** Ensures correct behavior of layers like dropout during training and evaluation.

# %% [markdown]
# <FONT COLOR="RED">**Here is the sample pseudocode for step 3.3**
#
# ```
# Set epochs to 5
# Initialize steps to 0, running_loss to 0, and valid_freq to 20
#
# For each epoch:
#     For each batch in training data:
#         Increment steps
#         Move input data and labels to device
#
#         Clear gradient
#         Perform forward pass to get log probabilities
#         Calculate loss using specified criterion
#         Perform backward pass to compute gradients
#         Update model parameters using optimizer
#
#         Accumulate running loss
#
#         If steps is a multiple of valid_freq:
#             Initialize valid_loss to 0 and accuracy to 0
#             Set model to evaluation mode
#             For each batch in validation data:
#                 Move validation data to device
#                 Perform forward pass for validation
#                 Calculate validation loss for the batch
#                 Accumulate validation loss
#                 Calculate exponentials of log probabilities
#                 Check equality between true labels and predicted labels
#                 Accumulate accuracy
#
#             Print epoch, training loss, validation loss, and validation accuracy
#             Reset running loss
#             Set model back to training mode
# ```
#
# ---

# %% [markdown]
# ### **Time for reflection!**

# %% [markdown]
# **Multiple Choice Questions:**
#
# 1. **What is the purpose of the line `model.train()` before starting the training loop?**
#    - A. It initializes the model architecture
#    - B. It sets the model in training mode, enabling dropout layers
#    - C. It defines image transformations
#    - D. It updates model parameters based on validation performance
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: B**

# %% [markdown]
# 2. **What does the line `model.forward(t_inputs)` in the training loop signify?**
#    - A. It initializes the training data
#    - B. It computes forward pass log probabilities for training data
#    - C. It resets the model's gradients
#    - D. It updates model parameters based on training data
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: B**

# %% [markdown]
# 3. **What is the purpose of using `torch.no_grad()` in the validation loop?**
#    - A. It disables gradient computation to save memory
#    - B. It enables data augmentation for validation
#    - C. It resets model parameters to their initial values
#    - D. It speeds up the validation process
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: A**

# %% [markdown]
# 4. **Why is the training loss printed as `running_loss/valid_freq` in the training loop?**
#    - A. To report the total running loss
#    - B. To provide the average loss over a specified interval
#    - C. To display the last computed loss
#    - D. To visualize model predictions
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: B**

# %% [markdown]
# 5. **What does the condition `if steps % valid_freq == 0` check for in the training loop?**
#    - A. It verifies the training data size
#    - B. It ensures proper validation frequency
#    - C. It monitors model accuracy
#    - D. It applies dropout to the model
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: B**

# %% [markdown]
# 6. **Why is the running loss reset to 0 after printing statistics in the training loop?**
#    - A. To terminate the training loop
#    - B. To provide a cumulative loss over all epochs
#    - C. To avoid accumulating loss from previous intervals
#    - D. To speed up the training process
#
# <details>
# <summary>Click to reveal the answer</summary>
#    - **Correct Option: C**

# %% [markdown]
# 7. **What does the line `model.to(device)` do in the training code?**
#     - A. It loads the model architecture
#     - B. It sets the device for model training
#     - C. It initializes the model parameters
#     - D. It enables data augmentation techniques
#
# <details>
# <summary>Click to reveal the answer</summary>
#     - **Correct Option: B**

# %% [markdown]
# ### ✌✈ ***:Step 3 Completed*** ✌✈

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 🚶📖✍ **Step 4 Starts** 🚶📖✍

# %% [markdown]
# ## **Step 4: Test Your Model**
#
# 1. **Objective:**
#    - Evaluate the performance of the trained network on previously unseen test data.
#    - Testing on a separate test set provides a reliable estimate of the model's generalization to new, unseen images.
#
# 2. **Procedure:**
#    - Run the test images through the trained network.
#    - Measure accuracy using the same approach as in validation.
#
# 3. **Expected Accuracy:**
#    - Aim for approximately 70% accuracy on the test set, indicating effective model training.
#
# 4. **Validation Comparison:**
#    - Validation and test accuracies serve as indicators of the model's overall performance.

# %% [markdown]
# <FONT COLOR="RED">**Here is the sample pseudocode for step 4**
# ```
# Initialize total_images as 0
# Initialize correct_classified as 0
#
# With no gradient calculation:
#     For each set of test inputs and labels from the testloader:
#         Move inputs and labels to the specified device
#         Calculate the maximum elements and corresponding predicted class using the trained model on inputs
#         Increment total_images
#         Calculate and update the count of correctly classified samples by comparing predicted and actual labels
# Print the percentage of correctly classified images (correct_classified/total_images * 100)
# ```

# %% [markdown]
# **Explaination of the Code:**
# 1. **Initialize Variables:**
#    - Initialize `total_images` and `correct_classified` to 0.
#
# 2. **Test Loop:**
#    - Iterate over each set of test inputs and labels from the testloader.
#
# 3. **Data Preparation:**
#    - Move inputs and labels to the specified device (e.g., GPU) to perform calculations.
#
# 4. **Model Prediction:**
#    - Use the trained model (`model`) to predict the classes for the test inputs (`s_inputs`).
#    - Find corresponding predicted class.
#
# 5. **Counting and Accumulation:**
#    - Increment `total_images` by the size (number of images in the current batch).
#    - Calculate the count of correctly classified samples by comparing predicted and actual labels.
#    - Increment `correct_classified` by the count of correctly classified samples.
#
# 6. **Print Result:**
#    - Print the percentage of correctly classified images out of the total processed images (`correct_classified/total_images * 100`).

# %% [markdown]
# ### ✌✈ ***:Step 4 Completed*** ✌✈

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 🚶📖✍ **Step 5 Starts** 🚶📖✍

# %% [markdown]
# ## **Step 5: Save and Load Your Model**
#
# #### **Step 5.1 Save Your Model**
# 1. **Objective:**
#    - Save the trained model to enable future use for making predictions.
#    - Save the mapping of classes to indices obtained from the training dataset (`image_datasets['train'].class_to_idx`).
#    - Attach the class-to-index mapping to the model as an attribute (`model.class_to_idx`) for easier inference.
#
# 2. **Rebuilding Considerations:**
#    - Keep in mind the need to completely rebuild the model later for inference purposes. Therefore, include all necessary information in the checkpoint for future model reconstruction.
#      - Save the model architecture, parameters, and learned weights.
#      - Include the class-to-index mapping for label interpretation.
#      - If planning to continue training later, save the number of epochs.
#      - Save the optimizer state (`optimizer.state_dict`) for continued training.
#
# 3. **Best Practice:**
#    - Save the checkpoint immediately after training to ensure easy access for subsequent tasks.

# %% [markdown]
# <FONT COLOR="RED">**Here is the sample pseudocode for step 5.1**
#
# ```
# Set the class-to-index mapping of the model to the class-to-index mapping of the training data
#
# Create a checkpoint dictionary with the following information:
#      'input_shape': e.g., 1024
#      'output_shape': 102
#      'classifier': The classifier of the model
#      'iterations': Number of epochs
#      'architecture': e.g., 'densenet121'
#      'learning_rate': e.g., 0.001
#      'class_to_idx': Class-to-index mapping of the model
#      'state_dict': State dictionary of the model
#      'optimizer': State dictionary of the optimizer
#
# Save the checkpoint dictionary to a file named 'check_point.pth'
# ```

# %% [markdown]
# **Explaination of the Code:**
#
# 1. **Set Class-to-Index Mapping:**
#    - Set the class-to-index mapping of the model to be the same as the class-to-index mapping of the training data.
#
# 2. **Create Checkpoint Dictionary:**
#    - Create a dictionary called `check_point` containing the following information:
#       - 'input_shape': The input shape of the model (e.g., 1024).
#       - 'output_shape': The output shape of the model (i.e., 102).
#       - 'classifier': The classifier of the model.
#       - 'iterations': The number of epochs (assumed to be stored in the variable `epochs`).
#       - 'architecture': The architecture of the model (assumed to be 'densenet121').
#       - 'learning_rate': The learning rate used during training (assumed to be 0.001).
#       - 'class_to_idx': The class-to-index mapping of the model.
#       - 'state_dict': The state dictionary of the model containing its parameters.
#       - 'optimizer': The state dictionary of the optimizer used during training.
#
# 3. **Save Checkpoint:**
#    - Save the created `check_point` dictionary to a file named 'check_point.pth'.

# %% [markdown]
# #### **Step 5.2 Load Your Model**
#
# 1. **Objective:**
#    - Develop a function to load a saved checkpoint and reconstruct the model.
#
# 2. **Motivation:**
#    - Facilitates the ability to resume work on the project without the need to retrain the network from scratch.
#    - Enables easy exploration, modification, and improvement of the trained model.

# %% [markdown]
# <FONT COLOR="RED">**Here is the sample pseudocode for step 5.2**
# ```
# Define a function named load_model that takes a filename as input:
#     Load the checkpoint from the specified filename (filename) using torch.load.
#
#     Create a model using the architecture specified in the checkpoint:
#         Get the architecture name from the checkpoint ('architecture').
#         Use torchvision.models to instantiate a model with the specified architecture, setting pretrained to True.
#
#     Set the model's classifier to the classifier stored in the checkpoint ('classifier').
#     Set the model's optimizer to the optimizer stored in the checkpoint optimizer').
#     Set the model's class-to-index mapping to the mapping stored in the checkpoint ('class_to_idx').
#     Load the model's state dictionary from the checkpoint ('state_dict').
#
#     Set the model's number of epochs to the iterations stored in the checkpoint ('iterations').
#     Set the model's learning rate to the learning rate stored in the checkpoint ('learning_rate').
#
#     Return the loaded model.
#
# Invoke the load_model function with the filename 'check_point.pth'.
# ```

# %% [markdown]
# **Explaination of the Code:**
#
# 1. **Define Load Function:**
#    - Define a function named `load_model` that takes a filename as input.
#
# 2. **Load Checkpoint:**
#    - Load the checkpoint from the specified filename using `torch.load`.
#
# 3. **Instantiate Model:**
#    - Extract the architecture name from the checkpoint.
#    - Use `torchvision.models` to instantiate a model with the specified architecture, setting `pretrained` to True.
#
# 4. **Transfer Components from Checkpoint:**
#    - Set the model's classifier to the classifier stored in the checkpoint.
#    - Set the model's optimizer to the optimizer stored in the checkpoint.
#    - Set the model's class-to-index mapping to the mapping stored in the checkpoint.
#    - Load the model's state dictionary from the checkpoint.
#
# 5. **Set Additional Model Attributes:**
#    - Set the model's number of epochs to the iterations stored in the checkpoint.
#    - Set the model's learning rate to the learning rate stored in the checkpoint.
#
# 6. **Return Loaded Model:**
#    - Return the loaded model.
#
# 7. **Invoke Load Function:**
#    - Invoke the `load_model` function with the filename 'check_point.pth'.

# %% [markdown]
# ### ✌✈ ***:Step 5 Completed*** ✌✈

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 🚶📖✍ **Step 6 Starts** 🚶📖✍

# %% [markdown]
# ## **Step 6: Using Model for Inference**
#
# #### **Step 6.1 Save Your Model**
